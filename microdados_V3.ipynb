# %%
"""
Este programa faz analise inicial dos dados do ENEM 2023

Funcionalidades:
- Analisara as respostas dos candidatos do ENEM 2023 para as questões de 1 a 5
    Q1: Até que série seu pai, ou o homem responsável por você, estudou?
    Q2: Até que série sua mãe, ou a mulher responsável por você, estudou?
    Q3: A partir da apresentação de algumas ocupações divididas em grupos ordenados, indique o grupo que contempla a ocupação mais próxima da ocupação do seu pai ou do homem responsável por você. (Se ele não estiver trabalhando, escolha uma ocupação pensando no último trabalho dele).
    Q4: A partir da apresentação de algumas ocupações divididas em grupos ordenados, indique o grupo que contempla a ocupação mais próxima da ocupação da sua mãe ou da mulher responsável por você. (Se ela não estiver trabalhando, escolha uma ocupação pensando no último trabalho dela).
    Q5: Incluindo você, quantas pessoas moram com você?



- faz a leitura dos dados do ENEM 2023 limpos no programa 01_enem_2023.ipynb
- cria os seguintes dicionarios para mapear os dados:
    - faixa etária: coluna TP_FAIXA_ETARIA
    - sexo: coluna TP_SEXO
    - estado civil: coluna TP_ESTADO_CIVIL
    - cor/raça: coluna TP_COR_RACA
    - nacionalidade: coluna TP_NACIONALIDADE
    - situação de conclusão do ensino médio: coluna TP_SITUACAO_CONCLUSAO
    - ano de conclusão do ensino médio: coluna TP_ANO_CONCLUIU
    - tipo de escola do ensino médio: coluna TP_ESCOLA
    - tipo de instiuição que concluiu ou concluirá o EM: coluna TP_ENSINO
    - candidato é treineiro: coluna IN_TREINEIRO
    - dependência administrativa da escola: coluna TP_DEPENDENCIA_ADM_ESC
    - localização da escola: coluna TP_LOCALIZACAO_ESC
    - sigla da UF da escola: coluna SG_UF_PROVA

- para cada dicionário foi plotado um histograma para visualização dos dados

"""
# Out:
# '\nEste programa faz analise inicial dos dados do ENEM 2023\n\nFuncionalidades:\n- Analisara as respostas dos candidatos do ENEM 2023 para as questões de 1 a 5\n    Q1: Até que série seu pai, ou o homem responsável por você, estudou?\n    Q2: Até que série sua mãe, ou a mulher responsável por você, estudou?\n    Q3: A partir da apresentação de algumas ocupações divididas em grupos ordenados, indique o grupo que contempla a ocupação mais próxima da ocupação do seu pai ou do homem responsável por você. (Se ele não estiver trabalhando, escolha uma ocupação pensando no último trabalho dele).\n    Q4: A partir da apresentação de algumas ocupações divididas em grupos ordenados, indique o grupo que contempla a ocupação mais próxima da ocupação da sua mãe ou da mulher responsável por você. (Se ela não estiver trabalhando, escolha uma ocupação pensando no último trabalho dela).\n    Q5: Incluindo você, quantas pessoas moram com você?\n\n\n\n- faz a leitura dos dados do ENEM 2023 limpos no pro
# ...

# %%
# Criando um dicionário para mapear os valores da coluna 'TP_FAIXA_ETARIA'
faixa_etaria = {
    1: '< 17',
    2: '17',
    3: '18',
    4: '19',
    5: '20',
    6: '21',
    7: '22',
    8: '23',
    9: '24',
    10: '25',
    11: '26 < 30',
    12: '31 < 35',
    13: '36 < 40',
    14: '41 < 45',
    15: '46 < 50',
    16: '51 < 55',
    17: '56 < 60',
    18: '61 < 65',
    19: '66 < 70',
    20: '> 70'
}


# Criando um dicionário para mapear os valores da coluna 'TP_SEXO'
sexo = {
    0: 'Feminino',
    1: 'Masculino',
}

# Criando um dicionário para mapear os valores da coluna 'TP_ESTADO_CIVIL'
estado_civil = {
    0: 'Não informado',
    1: 'Solteiro(a)',
    2: 'Casado(a)/Mora com companheiro(a)',
    3: 'Divorciado(a)/Desquitado(a)/Separado(a)',
    4: 'Viúvo(a)'
}

# Criando um dicionário para mapear os valores da coluna 'TP_COR_RACA'
cor_raca = {
    0: 'Não declarado',
    1: 'Branca',
    2: 'Preta',
    3: 'Parda',
    4: 'Amarela',
    5: 'Indígena',
    6: 'Não dispõe da informação'
}

# Criando um dicionário para mapear os valores da coluna 'TP_NACIONALIDADE'
nacionalidade = {
    0: 'Não informado',
    1: 'Brasileiro(a)',
    2: 'Brasileiro(a) Naturalizado(a)',
    3: 'Estrangeiro(a)',
    4: 'Brasileiro(a) Nato(a), nascido(a) no exterior'
}

# Criando um dicionário para mapear os valores da coluna 'TP_ST_CONCLUSAO'
st_conclusao = {
    1: 'Já concluí o Ensino Médio',
    2: 'Estou cursando e concluirei o Ensino Médio em 2023',
    3: 'Estou cursando e concluirei o Ensino Médio após 2023',
    4: 'Não concluí e não estou cursando o Ensino Médio'
}

# Criando um dicionário para mapear os valores da coluna 'TP_ANO_CONCLUIU'
ano_concluiu = {
    0: 'Não informado',
    1: '2022',
    2: '2021',
    3: '2020',
    4: '2019',
    5: '2018',
    6: '2017',
    7: '2016',
    8: '2015',
    9: '2014',
    10: '2013',
    11: '2012',
    12: '2011',
    13: '2010',
    14: '2009',
    15: '2008',
    16: '2007',
    17: '< 2007'
}

# Criando um dicionário para mapear os valores da coluna 'TP_ESCOLA'
escola = {
    1: 'Não Respondeu',
    2: 'Pública',
    3: 'Privada'
}

# Criando um dicionário para mapear os valores da coluna 'TP_ENSINO'
ensino = {
    -1: 'Desconhecido', # Este valor foi adicionado manualmente. NÃO ESTA PREVISTO NO DATASET ORIGINAL
    1: 'Regular',
    2: 'Educação Especial - Modalidade Substitutiva'
}

# Criando um dicionário para mapear os valores da coluna 'IN_TREINEIRO'
treineiro = {
    0: 'Não',
    1: 'Sim'
}

# Criando um dicionário para mapear os valores da coluna 'TP_DEPENDENCIA_ADM_ESC'
dependencia_adm_esc = {
    -1: 'Desconhecido', # Este valor foi adicionado manualmente. NÃO ESTA PREVISTO NO DATASET ORIGINAL
    1: 'Federal',
    2: 'Estadual',
    3: 'Municipal',
    4: 'Privada'
}

# Criando um dicionário para mapear os valores da coluna 'TP_LOCALIZACAO_ESC'
localizacao_esc = {
    -1: 'Desconhecido', # Este valor foi adicionado manualmente. NÃO ESTA PREVISTO NO DATASET ORIGINAL
    1: 'Urbana',
    2: 'Rural'
}

# Criando um dicionário para mapear os estados do Brasil
uf_brasil = {
    'AC': 'Acre',
    'AL': 'Alagoas',
    'AP': 'Amapá',
    'AM': 'Amazonas',
    'BA': 'Bahia',
    'CE': 'Ceará',
    'DF': 'Distrito Federal',
    'ES': 'Espírito Santo',
    'GO': 'Goiás',
    'MA': 'Maranhão',
    'MT': 'Mato Grosso',
    'MS': 'Mato Grosso do Sul',
    'MG': 'Minas Gerais',
    'PA': 'Pará',
    'PB': 'Paraíba',
    'PR': 'Paraná',
    'PE': 'Pernambuco',
    'PI': 'Piauí',
    'RJ': 'Rio de Janeiro',
    'RN': 'Rio Grande do Norte',
    'RS': 'Rio Grande do Sul',
    'RO': 'Rondônia',
    'RR': 'Roraima',
    'SC': 'Santa Catarina',
    'SP': 'São Paulo',
    'SE': 'Sergipe',
    'TO': 'Tocantins',
    'Desconhecido': 'Desconhecido' # Este valor foi adicionado manualmente. NÃO ESTA PREVISTO NO DATASET ORIGINAL
}

# Criando dicionário para mapear as respostas da Q1 a Q5

# Criando um dicionário para mapear os valores da coluna 'Q1': Até que série seu pai, ou o homem responsável por você, estudou?

q1 = {
    'A': 'Nunca estudou',
    'B': '< 5º ano do EF',
    'C': '< 9º ano do EF',
    'D': 'EM I',
    'E': '< SU I',
    'F': 'SU C e PG I',	
    'G': 'PG C',
    'H': 'Não sei'
}

# A questão Q2 é igual a Q1 mas se refere a mãe

# Criando um dicionário para mapear os valores da coluna 'Q3': A partir da apresentação de algumas ocupações divididas em grupos ordenados, indique o grupo que contempla a ocupação mais próxima da ocupação do seu pai ou do homem responsável por você. (Se ele não estiver trabalhando, escolha uma ocupação pensando no último trabalho dele).
q3 = {
    'A': 'Grupo 1',
    'B': 'Grupo 2',
    'C': 'Grupo 3',
    'D': 'Grupo 4',
    'E': 'Grupo 5',
    'F': 'Não sei',
}

'''
Grupo 1: Lavrador, agricultor sem empregados, bóia fria, criador de animais (gado, porcos, galinhas, ovelhas, cavalos etc.), apicultor, pescador, lenhador, seringueiro, extrativista.
Grupo 2: Diarista, empregado doméstico, cuidador de idosos, babá, cozinheiro (em casas particulares), motorista particular, jardineiro, faxineiro de empresas e prédios, vigilante, porteiro, carteiro, office-boy, vendedor, caixa, atendente de loja, auxiliar administrativo, recepcionista, servente de pedreiro, repositor de mercadoria.
Grupo 3: Padeiro, cozinheiro industrial ou em restaurantes, sapateiro, costureiro, joalheiro, torneiro mecânico, operador de máquinas, soldador, operário de fábrica, trabalhador da mineração, pedreiro, pintor, eletricista, encanador, motorista, caminhoneiro, taxista.
Grupo 4: Professor (de ensino fundamental ou médio, idioma, música, artes etc.), técnico (de enfermagem, contabilidade, eletrônica etc.), policial, militar de baixa patente (soldado, cabo, sargento), corretor de imóveis, supervisor, gerente, mestre de obras, pastor, microempresário (proprietário de empresa com menos de 10 empregados), pequeno comerciante, pequeno proprietário de terras, trabalhador autônomo ou por conta própria.
Grupo 5: Médico, engenheiro, dentista, psicólogo, economista, advogado, juiz, promotor, defensor, delegado, tenente, capitão, coronel, professor universitário, diretor em empresas públicas ou privadas, político, proprietário de empresas com mais de 10 empregados.
'''

# A questão Q4 é igual a Q3 mas se refere a mãe

# A questão Q5 é um valor numérico, não é necessário criar um dicionário
# Out:
# '\nGrupo 1: Lavrador, agricultor sem empregados, bóia fria, criador de animais (gado, porcos, galinhas, ovelhas, cavalos etc.), apicultor, pescador, lenhador, seringueiro, extrativista.\nGrupo 2: Diarista, empregado doméstico, cuidador de idosos, babá, cozinheiro (em casas particulares), motorista particular, jardineiro, faxineiro de empresas e prédios, vigilante, porteiro, carteiro, office-boy, vendedor, caixa, atendente de loja, auxiliar administrativo, recepcionista, servente de pedreiro, repositor de mercadoria.\nGrupo 3: Padeiro, cozinheiro industrial ou em restaurantes, sapateiro, costureiro, joalheiro, torneiro mecânico, operador de máquinas, soldador, operário de fábrica, trabalhador da mineração, pedreiro, pintor, eletricista, encanador, motorista, caminhoneiro, taxista.\nGrupo 4: Professor (de ensino fundamental ou médio, idioma, música, artes etc.), técnico (de enfermagem, contabilidade, eletrônica etc.), policial, militar de baixa patente (soldado, cabo, sargento), corret
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Importação dos arquivo tratado
microdados = pd.read_csv('microdados_tratado.csv', sep=';', encoding='ISO-8859-1')

# %%
"""
Leitura do arquivo JSON com os tipos de dados de cada coluna
Atualizar o arquivo JSON com os tipos de dados corretos e otimizados
"""
dtypes = pd.read_json("dtypes.json", typ='series')
microdados = microdados.astype(dtypes)

# %%
# Criando função para plotar histograma
def plot_histograma(coluna, dicionario, titulo, rotation_bar=0, pad=0):
    # Contando a quantidade de valores de cada tipo
    count = microdados[coluna].value_counts().reindex(dicionario.keys())

    # Criando o histograma
    histograma = count.plot(kind='bar')
    # Adicionando os valores no topo das barras
    for index, value in enumerate(count):
        # parametros do text: x, y, texto, alinhamento horizontal, alinhamento vertical, rotação
        histograma.text(index, value, str(value), ha='center', va='bottom', rotation=rotation_bar)

    # Adicionando os rótulos do eixo x
    histograma.set_xticklabels(dicionario.values(), rotation=90)
    # Adicionando o título ao gráfico
    plt.title(titulo, pad=pad)
    # Exibindo o gráfico
    plt.show()

# %%
def plot_histograma_com_legenda(microdados, legenda, colunas, titulo, titulo_legenda):
    plt.bar(microdados[colunas].value_counts().index, microdados[colunas].value_counts().values, label=legenda)
    plt.title(titulo)
    plt.xlabel('Resposta')
    plt.ylabel('Quantidade')
    plt.legend(legenda, title=titulo_legenda)
    plt.grid(axis='y')
    plt.show()

# %%
# Criando a legenda para o gráfico:
# Será texto com o valor da resposta e a descrição da resposta
legenda = []
for key, value in q1.items():
    legenda.append(f'{key}: {value}')

# %%
# Chamada da função
plot_histograma_com_legenda(microdados, legenda, 'Q001', 'Distribuição das respostas da Q1 Estudantes Sexo Masculino: Escolaridade do pai', 'Escolaridade do pai')

# %%
# Analisando a resposta Q001 pelo sexo masculino

# Filtrando os dados para o sexo masculino
df_masc = microdados[microdados['TP_SEXO'] == 1]

plot_histograma_com_legenda(df_masc, legenda, 'Q001', 'Distribuição das respostas da Q1 Estudantes Sexo Masculino: Escolaridade do pai', 'Escolaridade do pai')

# %%
# Filtrando os dados para o sexo feminino
df_fem = microdados[microdados['TP_SEXO'] == 0]

plot_histograma_com_legenda(df_fem, legenda, 'Q001', 'Distribuição das respostas da Q1 Estudantes Sexo Feminino: Escolaridade do pai', 'Escolaridade do pai')

# %%
# Analisando a resposta Q001 pela raça

# Filtrando os dados para a raça branca
df_branco = microdados[microdados['TP_COR_RACA'] == 1]

plot_histograma_com_legenda(df_branco, legenda, 'Q001', 'Distribuição das respostas da Q1 Estudantes Raça Branca: Escolaridade do pai', 'Escolaridade do pai')

# %%
# Analisando a resposta Q001 pela raça

# Filtrando os dados para a raça preta
df_preto = microdados[microdados['TP_COR_RACA'] == 2]

plot_histograma_com_legenda(df_preto, legenda, 'Q001', 'Distribuição das respostas da Q1 Estudantes Raça Preta: Escolaridade do pai', 'Escolaridade do pai')

# %%
# Analisando a resposta Q001 pela raça

# Filtrando os dados para a raça parda
df_pardo = microdados[microdados['TP_COR_RACA'] == 3]

plot_histograma_com_legenda(df_pardo, legenda, 'Q001', 'Distribuição das respostas da Q1 Estudantes Raça Parda: Escolaridade do pai', 'Escolaridade do pai')

# %%
# Analisando a resposta Q002: Escoralidade da mãe

# Serão criados 4 gráficos para analisar a distribuição das respostas da Q002
# 1 - Geral
# 2 - Raça Branca
# 3 - Raça Preta
# 4 - Raça Parda

fig, axs = plt.subplots(2, 2, figsize=(16, 10))

# Gráfico 1 - Geral
axs[0, 0].bar(microdados['Q002'].value_counts().index, microdados['Q002'].value_counts().values, label=legenda)
axs[0, 0].set_title('Distribuição das respostas da Q2 - Escolaridade da mãe', fontsize=12)
axs[0, 0].set_xlabel('Resposta')
axs[0, 0].set_ylabel('Quantidade')
axs[0, 0].legend(legenda, title = 'Escolaridade da mãe')
# incluindo o número em cima das barras
for i in range(len(microdados['Q002'].value_counts().index)):
    axs[0, 0].text(i, microdados['Q002'].value_counts().values[i], microdados['Q002'].value_counts().values[i], ha = 'center', va = 'bottom')

# Gráfico 2 - Raça Branca
microdados_branco = microdados[microdados['TP_COR_RACA'] == 1]
axs[0, 1].bar(microdados_branco['Q002'].value_counts().index, microdados_branco['Q002'].value_counts().values, label=legenda)
axs[0, 1].set_title('Distribuição das respostas da Q2 Estudantes Raça Branca: Escolaridade da mãe', fontsize=12)
axs[0, 1].set_xlabel('Resposta')
axs[0, 1].set_ylabel('Quantidade')
axs[0, 1].legend(legenda, title = 'Escolaridade da mãe')
# incluindo o número em cima das barras
for i in range(len(microdados_branco['Q002'].value_counts().index)):
    axs[0, 1].text(i, microdados_branco['Q002'].value_counts().values[i], microdados_branco['Q002'].value_counts().values[i], ha = 'center', va = 'bottom')


# Gráfico 3 - Raça Preta
microdados_branco = microdados[microdados['TP_COR_RACA'] == 2]
axs[1, 0].bar(microdados_branco['Q002'].value_counts().index, microdados_branco['Q002'].value_counts().values, label=legenda)
axs[1, 0].set_title('Distribuição das respostas da Q2 Estudantes Raça Preta: Escolaridade da mãe', fontsize=12)
axs[1, 0].set_xlabel('Resposta')
axs[1, 0].set_ylabel('Quantidade')
axs[1, 0].legend(legenda, title = 'Escolaridade da mãe')
# incluindo o número em cima das barras
for i in range(len(microdados_branco['Q002'].value_counts().index)):
    axs[1, 0].text(i, microdados_branco['Q002'].value_counts().values[i], microdados_branco['Q002'].value_counts().values[i], ha = 'center', va = 'bottom')

# Gráfico 4 - Raça Parda
microdados_branco = microdados[microdados['TP_COR_RACA'] == 3]
axs[1, 1].bar(df_branco['Q002'].value_counts().index, df_branco['Q002'].value_counts().values, label=legenda)
axs[1, 1].set_title('Distribuição das respostas da Q2 Estudantes Raça Parda: Escolaridade da mãe', fontsize=12)
axs[1, 1].set_xlabel('Resposta')
axs[1, 1].set_ylabel('Quantidade')
axs[1, 1].legend(legenda, title = 'Escolaridade da mãe')
# incluindo o número em cima das barras
for i in range(len(df_branco['Q002'].value_counts().index)):
    axs[1, 1].text(i, df_branco['Q002'].value_counts().values[i], df_branco['Q002'].value_counts().values[i], ha = 'center', va = 'bottom')

plt.tight_layout()
plt.show()

# %%
# Analisando a resposta Q003: Grupo de ocupação do pai

# Verificando os tipos de respostas da Q003
# Imprimindo os valores únicos da coluna 'Q003'
print(microdados['Q003'].unique())

# Criando a legenda para o gráfico:
# Será texto com o valor da resposta e a descrição da resposta
legenda = []
for key, value in q3.items():
    legenda.append(f'{key}: {value}')

# Serão criados 4 gráficos para analisar a distribuição das respostas da Q003
# 1 - Geral
# 2 - Raça Branca
# 3 - Raça Preta
# 4 - Raça Parda

fig, axs = plt.subplots(2, 2, figsize=(16, 10))

# Gráfico 1 - Geral
axs[0, 0].bar(microdados['Q003'].value_counts().index, microdados['Q003'].value_counts().values, label=legenda)
axs[0, 0].set_title('Distribuição das respostas da Q3 - Grupo de ocupação do pai', fontsize=12)
axs[0, 0].set_xlabel('Resposta')
axs[0, 0].set_ylabel('Quantidade')
axs[0, 0].legend(legenda, title = 'Grupo de ocupação do pai')
# incluindo o número em cima das barras
for i in range(len(microdados['Q003'].value_counts().index)):
    axs[0, 0].text(i, microdados['Q003'].value_counts().values[i], microdados['Q003'].value_counts().values[i], ha = 'center', va = 'bottom')

# Gráfico 2 - Raça Branca
microdados_branco = microdados[microdados['TP_COR_RACA'] == 1]
axs[0, 1].bar(microdados_branco['Q003'].value_counts().index, microdados_branco['Q003'].value_counts().values, label=legenda)
axs[0, 1].set_title('Distribuição das respostas da Q3 Estudantes Raça Branca: Grupo de ocupação do pai', fontsize=12)
axs[0, 1].set_xlabel('Resposta')
axs[0, 1].set_ylabel('Quantidade')
axs[0, 1].legend(legenda, title = 'Grupo de ocupação do pai')
# incluindo o número em cima das barras
for i in range(len(microdados_branco['Q003'].value_counts().index)):
    axs[0, 1].text(i, microdados_branco['Q003'].value_counts().values[i], microdados_branco['Q003'].value_counts().values[i], ha = 'center', va = 'bottom')

# Gráfico 3 - Raça Preta
microdados_branco = microdados[microdados['TP_COR_RACA'] == 2]
axs[1, 0].bar(microdados_branco['Q003'].value_counts().index, microdados_branco['Q003'].value_counts().values, label=legenda)
axs[1, 0].set_title('Distribuição das respostas da Q3 Estudantes Raça Preta: Grupo de ocupação do pai', fontsize=12)
axs[1, 0].set_xlabel('Resposta')
axs[1, 0].set_ylabel('Quantidade')
axs[1, 0].legend(legenda, title = 'Grupo de ocupação do pai')
# incluindo o número em cima das barras
for i in range(len(microdados_branco['Q003'].value_counts().index)):
    axs[1, 0].text(i, microdados_branco['Q003'].value_counts().values[i], microdados_branco['Q003'].value_counts().values[i], ha = 'center', va = 'bottom')

# Gráfico 4 - Raça Parda
microdados_branco = microdados[microdados['TP_COR_RACA'] == 3]
axs[1, 1].bar(microdados_branco['Q003'].value_counts().index, microdados_branco['Q003'].value_counts().values, label=legenda)
axs[1, 1].set_title('Distribuição das respostas da Q3 Estudantes Raça Parda: Grupo de ocupação do pai', fontsize=12)
axs[1, 1].set_xlabel('Resposta')
axs[1, 1].set_ylabel('Quantidade')
axs[1, 1].legend(legenda, title = 'Grupo de ocupação do pai')
# incluindo o número em cima das barras
for i in range(len(microdados_branco['Q003'].value_counts().index)):
    axs[1, 1].text(i, microdados_branco['Q003'].value_counts().values[i], microdados_branco['Q003'].value_counts().values[i], ha = 'center', va = 'bottom')

plt.tight_layout()
plt.show()
# Out:
# ['E', 'C', 'B', 'A', 'D', 'F']
# Categories (6, object): ['A', 'B', 'C', 'D', 'E', 'F']

# %%
# Analisando a resposta Q004: Grupo de ocupação da mãe

# Verificando os tipos de respostas da Q004


# Serão criados 4 gráficos para analisar a distribuição das respostas da Q004
# 1 - Geral
# 2 - Raça Branca
# 3 - Raça Preta
# 4 - Raça Parda

fig, axs = plt.subplots(2, 2, figsize=(16, 10))

# Gráfico 1 - Geral
axs[0, 0].bar(microdados['Q004'].value_counts().index, microdados['Q004'].value_counts().values, label=legenda)
axs[0, 0].set_title('Distribuição das respostas da Q4 - Grupo de ocupação da mãe', fontsize=12)
axs[0, 0].set_xlabel('Resposta')
axs[0, 0].set_ylabel('Quantidade')
axs[0, 0].legend(legenda, title = 'Grupo de ocupação da mãe')
# incluindo o número em cima das barras
for i in range(len(microdados['Q004'].value_counts().index)):
    axs[0, 0].text(i, microdados['Q004'].value_counts().values[i], microdados['Q004'].value_counts().values[i], ha = 'center', va = 'bottom')

# Gráfico 2 - Raça Branca
microdados_branco = microdados[microdados['TP_COR_RACA'] == 1]
axs[0, 1].bar(microdados_branco['Q004'].value_counts().index, microdados_branco['Q004'].value_counts().values, label=legenda)
axs[0, 1].set_title('Distribuição das respostas da Q4 Estudantes Raça Branca: Grupo de ocupação da mãe', fontsize=12)
axs[0, 1].set_xlabel('Resposta')
axs[0, 1].set_ylabel('Quantidade')
axs[0, 1].legend(legenda, title = 'Grupo de ocupação da mãe')
# incluindo o número em cima das barras
for i in range(len(microdados_branco['Q004'].value_counts().index)):
    axs[0, 1].text(i, microdados_branco['Q004'].value_counts().values[i], microdados_branco['Q004'].value_counts().values[i], ha = 'center', va = 'bottom')

# Gráfico 3 - Raça Preta
microdados_branco = microdados[microdados['TP_COR_RACA'] == 2]
axs[1, 0].bar(microdados_branco['Q004'].value_counts().index, microdados_branco['Q004'].value_counts().values, label=legenda)
axs[1, 0].set_title('Distribuição das respostas da Q4 Estudantes Raça Preta: Grupo de ocupação da mãe', fontsize=12)
axs[1, 0].set_xlabel('Resposta')
axs[1, 0].set_ylabel('Quantidade')
axs[1, 0].legend(legenda, title = 'Grupo de ocupação da mãe')
# incluindo o número em cima das barras
for i in range(len(microdados_branco['Q004'].value_counts().index)):
    axs[1, 0].text(i, microdados_branco['Q004'].value_counts().values[i], microdados_branco['Q004'].value_counts().values[i], ha = 'center', va = 'bottom')

# Gráfico 4 - Raça Parda
microdados_branco = microdados[microdados['TP_COR_RACA'] == 3]
axs[1, 1].bar(microdados_branco['Q004'].value_counts().index, microdados_branco['Q004'].value_counts().values, label=legenda)
axs[1, 1].set_title('Distribuição das respostas da Q4 Estudantes Raça Parda: Grupo de ocupação da mãe', fontsize=12)
axs[1, 1].set_xlabel('Resposta')
axs[1, 1].set_ylabel('Quantidade')
axs[1, 1].legend(legenda, title = 'Grupo de ocupação da mãe')
# incluindo o número em cima das barras
for i in range(len(microdados_branco['Q004'].value_counts().index)):
    axs[1, 1].text(i, microdados_branco['Q004'].value_counts().values[i], microdados_branco['Q004'].value_counts().values[i], ha = 'center', va = 'bottom')

plt.tight_layout()
plt.show()

# %%
# Analisando a resposta Q005: Quantidade de pessoas que moram com o estudante

# Verificando os tipos de respostas da Q005
# Imprimindo os valores únicos da coluna 'Q005'
print(microdados['Q005'].unique())

# Serão criados 4 gráficos para analisar a distribuição das respostas da Q005
# 1 - Geral
# 2 - Raça Branca
# 3 - Raça Preta
# 4 - Raça Parda

fig, axs = plt.subplots(2, 2, figsize=(16, 10))

# Gráfico 1 - Geral
axs[0, 0].bar(microdados['Q005'].value_counts().index, microdados['Q005'].value_counts().values)
axs[0, 0].set_title('Distribuição das respostas da Q5\nQuantidade de pessoas que moram com o estudante', fontsize=12)
axs[0, 0].set_xlabel('Resposta')
axs[0, 0].set_ylabel('Quantidade')
axs[0, 0].grid(axis='y')
#  Legenda do eixo x será a quantidade de pessoas que moram com o estudante
axs[0, 0].set_xticks(microdados['Q005'].value_counts().index)


# Gráfico 2 - Raça Branca
microdados_branco = microdados[microdados['TP_COR_RACA'] == 1]
axs[0, 1].bar(microdados_branco['Q005'].value_counts().index, microdados_branco['Q005'].value_counts().values)
axs[0, 1].set_title('Distribuição das respostas da Q5\nEstudantes Raça Branca: Quantidade de pessoas que moram com o estudante', fontsize=12)
axs[0, 1].set_xlabel('Resposta')
axs[0, 1].set_ylabel('Quantidade')
axs[0, 1].grid(axis='y')
# Legenda do eixo x será a quantidade de pessoas que moram com o estudante
axs[0, 1].set_xticks(microdados['Q005'].value_counts().index)

# Gráfico 3 - Raça Preta
microdados_branco = microdados[microdados['TP_COR_RACA'] == 2]
axs[1, 0].bar(microdados_branco['Q005'].value_counts().index, microdados_branco['Q005'].value_counts().values)
axs[1, 0].set_title('Distribuição das respostas da Q5\nEstudantes Raça Preta: Quantidade de pessoas que moram com o estudante', fontsize=12)
axs[1, 0].set_xlabel('Resposta')
axs[1, 0].set_ylabel('Quantidade')
axs[1, 0].grid(axis='y')
# Legenda do eixo x será a quantidade de pessoas que moram com o estudante
axs[1, 0].set_xticks(microdados['Q005'].value_counts().index)

# Gráfico 4 - Raça Parda
microdados_branco = microdados[microdados['TP_COR_RACA'] == 3]
axs[1, 1].bar(microdados_branco['Q005'].value_counts().index, microdados_branco['Q005'].value_counts().values)
axs[1, 1].set_title('Distribuição das respostas da Q5\nEstudantes Raça Parda: Quantidade de pessoas que moram com o estudante', fontsize=12)
axs[1, 1].set_xlabel('Resposta')
axs[1, 1].set_ylabel('Quantidade')
axs[1, 1].grid(axis='y')
# Legenda do eixo x será a quantidade de pessoas que moram com o estudante
axs[1, 1].set_xticks(microdados['Q005'].value_counts().index)

plt.tight_layout()
plt.show()
# Out:
# [ 5  3  4  1  2  6  7 13  8 10 20  9 11 12 15 17 14 18 16 19]
